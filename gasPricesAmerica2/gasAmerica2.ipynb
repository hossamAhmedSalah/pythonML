# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import sklearn
from sklearn import model_selection
from sklearn import linear_model
#USAG = pd.read_excel('gasInmonths.xls')
#USAG
mon_price = pd.read_excel('gasm2.xlsx')
print(mon_price, ("=="*100))
plt.figure(figsize=(10,3), dpi=150)
plt.plot(mon_price.Date,mon_price.US_gas_price,'r,-', label='months/priceOFgas')
plt.title("gas prices in America")
plt.legend()
plt.show()
# Out:
#           Date  US_gas_price
# 0   1993-04-15         1.078
# 1   1993-05-15         1.100
# 2   1993-06-15         1.097
# 3   1993-07-15         1.078
# 4   1993-08-15         1.062
# ..         ...           ...
# 347 2022-03-15         4.322
# 348 2022-04-15         4.213
# 349 2022-05-15         4.545
# 350 2022-06-15         5.032
# 351 2022-07-15         4.668
#
# [352 rows x 2 columns] ========================================================================================================================================================================================================

# %%
mon_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          352 non-null    datetime64[ns]
#  1   US_gas_price  352 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.6 KB

# %%
x = mon_price['Date'].to_numpy().reshape(-1,1)

#for i in range(len(x)):
   # x[i] = int(x[i])
    #print(int(x[i]),",")

#sorry I have to cheat🐍 
xNew = np.array([734832000000000000 ,
737424000000000000 ,
740102400000000000 ,
742694400000000000 ,
745372800000000000 ,
748051200000000000 ,
750643200000000000 ,
753321600000000000 ,
755913600000000000 ,
758592000000000000 ,
761270400000000000 ,
763689600000000000 ,
766368000000000000 ,
768960000000000000 ,
771638400000000000 ,
774230400000000000 ,
776908800000000000 ,
779587200000000000 ,
782179200000000000 ,
784857600000000000 ,
787449600000000000 ,
790128000000000000 ,
792806400000000000 ,
795225600000000000 ,
797904000000000000 ,
800496000000000000 ,
803174400000000000 ,
805766400000000000 ,
808444800000000000 ,
811123200000000000 ,
813715200000000000 ,
816393600000000000 ,
818985600000000000 ,
821664000000000000 ,
824342400000000000 ,
826848000000000000 ,
829526400000000000 ,
832118400000000000 ,
834796800000000000 ,
837388800000000000 ,
840067200000000000 ,
842745600000000000 ,
845337600000000000 ,
848016000000000000 ,
850608000000000000 ,
853286400000000000 ,
855964800000000000 ,
858384000000000000 ,
861062400000000000 ,
863654400000000000 ,
866332800000000000 ,
868924800000000000 ,
871603200000000000 ,
874281600000000000 ,
876873600000000000 ,
879552000000000000 ,
882144000000000000 ,
884822400000000000 ,
887500800000000000 ,
889920000000000000 ,
892598400000000000 ,
895190400000000000 ,
897868800000000000 ,
900460800000000000 ,
903139200000000000 ,
905817600000000000 ,
908409600000000000 ,
911088000000000000 ,
913680000000000000 ,
916358400000000000 ,
919036800000000000 ,
921456000000000000 ,
924134400000000000 ,
926726400000000000 ,
929404800000000000 ,
931996800000000000 ,
934675200000000000 ,
937353600000000000 ,
939945600000000000 ,
942624000000000000 ,
945216000000000000 ,
947894400000000000 ,
950572800000000000 ,
953078400000000000 ,
955756800000000000 ,
958348800000000000 ,
961027200000000000 ,
963619200000000000 ,
966297600000000000 ,
968976000000000000 ,
971568000000000000 ,
974246400000000000 ,
#        [1.078],
#        [1.062],
#        [1.05 ],
#        [1.092],
#        [1.066],
#        [1.014],
#        [0.998],
#        [1.009],
#        [1.008],
#        [1.027],
#        [1.047],
#        [1.078],
#        [1.106],
#        [1.155],
#        [1.144],
#        [1.114],
#        [1.119],
#        [1.129],
#        [1.13 ],
#        [1.12 ],
#        [1.119],
#        [1.157],
#        [1.225],
#        [1.239],
#        [1.201],
#        [1.17 ],
#        [1.158],
#        [1.134],
#        [1.109],
#        [1.118],
#        [1.137],
#        [1.136],
#        [1.183],
#        [1.275],
#        [1.324],
#        [1.3  ],
#        [1.272],
#        [1.251],
#        [1.247],
#        [1.249],
#        [1.278],
#        [1.282],
#        [1.283],
#        [1.276],
#        [1.251],
#        [1.244],
#        [1.245],
#        [1.242],
#        [1.22 ],
#        [1.268],
#        [1.276],
#        [1.242],
# ...

# %%
#x_train, x_test, y_train, y_test = model_selection.train_test_split(x,y,test_size=1/3, random_state=0)
x_train, x_test, y_train, y_test = model_selection.train_test_split(X,y,test_size=1/3, random_state=0)
print("Training data shapes:\n\tX:", x_train.shape, "\n\tY:", y_train.shape,
      "\nTesting data shapes:\n\tX:", x_test.shape, "\n\tY:", y_test.shape)
# Out:
# Training data shapes:
# 	X: (234, 1)
# 	Y: (234, 1)
# Testing data shapes:
# 	X: (118, 1)
# 	Y: (118, 1)

# %%
x_train
# Out:
# array([[1066176000000000000],
#        [1368576000000000000],
#        [1479168000000000000],
#        [1365984000000000000],
#        [1137283200000000000],
#        [ 748051200000000000],
#        [ 821664000000000000],
#        [1605398400000000000],
#        [1473897600000000000],
#        [ 824342400000000000],
#        [1160870400000000000],
#        [ 989884800000000000],
#        [ 958348800000000000],
#        [1552608000000000000],
#        [1387065600000000000],
#        [1639526400000000000],
#        [1197676800000000000],
#        [1150329600000000000],
#        [1018828800000000000],
#        [ 855964800000000000],
#        [1471219200000000000],
#        [1184457600000000000],
#        [ 926726400000000000],
#        [1095206400000000000],
#        [1613347200000000000],
#        [1231977600000000000],
#        [1152921600000000000],
#        [ 811123200000000000],
#        [1347667200000000000],
#        [1489536000000000000],
#        [ 805766400000000000],
# ...

# %%
y_test.reshape(-1,1)
# Out:
# array([[1.092],
#        [1.268],
#        [2.997],
#        [1.283],
#        [3.264],
#        [3.048],
#        [2.765],
#        [3.688],
#        [1.483],
#        [1.571],
#        [2.42 ],
#        [0.987],
#        [3.958],
#        [2.013],
#        [3.615],
#        [2.023],
#        [1.954],
#        [3.42 ],
#        [4.668],
#        [3.779],
#        [2.783],
#        [2.681],
#        [1.324],
#        [2.705],
#        [2.67 ],
#        [1.239],
#        [1.106],
#        [1.92 ],
#        [1.285],
#        [3.75 ],
#        [1.065],
#        [1.077],
#        [1.242],
#        [1.429],
#        [1.216],
#        [1.357],
#        [3.667],
#        [2.706],
#        [3.326],
#        [1.129],
#        [2.359],
#        [1.588],
#        [2.546],
#        [3.44 ],
#        [1.486],
#        [1.533],
#        [1.212],
#        [2.071],
#        [2.785],
#        [3.611],
#        [3.596],
#        [3.128],
#        [2.621],
#        [1.066],
#        [1.049],
# ...

# %%
reg = sklearn.linear_model.LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction = reg.predict(x_test)
print(y_prediction)
# Out:
# [[1.13123149]
#  [1.44181825]
#  [2.83968054]
#  [1.39478654]
#  [2.53597106]
#  [2.5222165 ]
#  [2.10358991]
#  [2.81239328]
#  [1.71202874]
#  [1.69849603]
#  [3.33950339]
#  [1.54985808]
#  [2.63025632]
#  [1.99555008]
#  [2.54218279]
#  [1.98867281]
#  [2.00220552]
#  [2.75182886]
#  [3.46063223]
#  [2.70435345]
#  [2.49515108]
#  [3.23124171]
#  [1.34043386]
#  [3.1032356 ]
#  [2.41417667]
#  [1.26611488]
#  [1.19179591]
#  [2.00908279]
#  [1.61729977]
#  [2.79886057]
#  [1.52279266]
#  [1.49572724]
#  [1.45535096]
#  [1.87397755]
#  [1.46222824]
#  [1.77947043]
#  [2.58300277]
#  [2.43458666]
#  [2.60319091]
#  [1.2257386 ]
#  [2.99497393]
#  [1.6918406 ]
#  [2.86630227]
#  [2.61006818]
#  [1.86044484]
#  [1.91435383]
#  [1.78634771]
#  [2.94749852]
#  [2.48161837]
#  [3.42735507]
#  [2.64378903]
#  [2.272416  ]
#  [3.07594833]
#  [1.13810876]
#  [1.52966994]
#  [2.75870614]
#  [2.74517343]
#  [2.84633597]
#  [1.60376706]
#  [1.48884996]
#  [1.76593773]
#  [1.98201738]
# ...

# %%
y_test
# Out:
# array([[1.092],
#        [1.268],
#        [2.997],
#        [1.283],
#        [3.264],
#        [3.048],
#        [2.765],
#        [3.688],
#        [1.483],
#        [1.571],
#        [2.42 ],
#        [0.987],
#        [3.958],
#        [2.013],
#        [3.615],
#        [2.023],
#        [1.954],
#        [3.42 ],
#        [4.668],
#        [3.779],
#        [2.783],
#        [2.681],
#        [1.324],
#        [2.705],
#        [2.67 ],
#        [1.239],
#        [1.106],
#        [1.92 ],
#        [1.285],
#        [3.75 ],
#        [1.065],
#        [1.077],
#        [1.242],
#        [1.429],
#        [1.216],
#        [1.357],
#        [3.667],
#        [2.706],
#        [3.326],
#        [1.129],
#        [2.359],
#        [1.588],
#        [2.546],
#        [3.44 ],
#        [1.486],
#        [1.533],
#        [1.212],
#        [2.071],
#        [2.785],
#        [3.611],
#        [3.596],
#        [3.128],
#        [2.621],
#        [1.066],
#        [1.049],
# ...

# %%
plt.figure(figsize=(10,3), dpi=150)
plt.plot(mon_price.Date,mon_price.US_gas_price,'r,-', label='months/priceOFgas')
plt.title("gas prices in America")
plt.legend()
plt.show()
plt.plot(x_test, y_prediction,  color = 'green')

# %%
from sklearn.metrics import mean_squared_error

score = reg.score(x_test, y_test)
print("R-squared:", score)
print("MSE:", mean_squared_error(y_true=y_test, y_pred=y_prediction))
# Out:
# R-squared: 0.628149818914788
# MSE: 0.3164616784330223
